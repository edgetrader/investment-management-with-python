# %% [markdown]
# ## Quiz 2

# %%
import sys  
sys.path.append('../src') 
from edhec_risk_kit import *
import edhec_risk_kit as erk

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

DATA_FOLDER = '../data/'

# %matplotlib inline

# %%
quiz = pd.read_csv(DATA_FOLDER + 'edhec-hedgefundindices.csv', header=0, index_col=0, 
                   parse_dates=True, na_values=-99.99)

# %%
quiz['2000':]
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 2000-01-31                   2.27        1.28                   0.88
# 2000-02-29                   2.67       -0.22                   4.21
# 2000-03-31                   2.43       -1.38                   1.03
# 2000-04-30                   2.23       -2.41                  -1.01
# 2000-05-31                   1.49        1.14                  -1.32
# ...                           ...         ...                    ...
# 2018-07-31                   0.21       -0.58                   0.93
# 2018-08-31                   0.24        1.66                   0.02
# 2018-09-30                   0.34       -0.54                   0.50
# 2018-10-31                  -0.73       -3.14                  -1.58
# 2018-11-30                  -0.68       -0.53                  -1.93
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
erk.var_gaussian(quiz['2000':]['Distressed Securities'], 1)
# Out:
# 3.143017693928045

# %%
erk.var_gaussian(quiz['2000':][['Distressed Securities']], level=1, modified=True)
# Out:
# Distressed Securities    4.966909
# dtype: float64

# %%
erk.var_gaussian(quiz['2000':][['Distressed Securities']], level=1, modified=True)
# Out:
# Distressed Securities    4.966909
# dtype: float64

# %%
import pandas as pd
import edhec_risk_kit as erk 
ind = pd.read_csv("../data/edhec-hedgefundindices.csv",
                  header =0, index_col = 0, parse_dates=True)/100
    
ind00 = ind["2000":]

# %%
erk.var_gaussian(ind00[["Distressed Securities"]],level=1)
# Out:
# Distressed Securities    0.03143
# dtype: float64

# %%
erk.var_gaussian(ind00[["Distressed Securities"]],level=1, modified=True)
# Out:
# Distressed Securities    0.049669
# dtype: float64

# %%
erk.var_gaussian(ind00["Distressed Securities"],level=1)
# Out:
# 0.031430176939280456

# %%
erk.var_historic(quiz['2000':]['Distressed Securities'], 1)
# Out:
# 4.264199999999999

# %%
data = erk.get_ind_returns()
data['2013':'2017']
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 2013-01  0.0554  0.0507  0.0561  0.1313  0.0513  0.0869  0.0256  0.0807
# 2013-02  0.0384  0.0522  0.0221  0.0000 -0.0654  0.0314  0.0146  0.0135
# 2013-03  0.0656  0.0531  0.0272  0.0769  0.0778  0.0219  0.0288  0.0651
# 2013-04  0.0284  0.0355  0.0440  0.0451 -0.0029  0.0135  0.0903  0.0259
# 2013-05 -0.0345 -0.0147 -0.0298  0.0218  0.0479 -0.0022  0.0078  0.0163
# 2013-06  0.0084  0.0093 -0.0226 -0.0375  0.0246 -0.0072  0.0058 -0.0136
# 2013-07  0.0326  0.0273  0.0176  0.0478  0.1207  0.0498  0.0172  0.0788
# 2013-08 -0.0375 -0.0386 -0.0485  0.0247 -0.0488 -0.0285 -0.0186 -0.0381
# 2013-09  0.0031  0.0134  0.0428  0.0991  0.0626  0.0093  0.0765  0.0401
# 2013-10  0.0461  0.0625  0.0535  0.0455  0.0718  0.0607  0.0240  0.0382
# 2013-11  0.0152  0.0115 -0.0242  0.0313  0.0021  0.0395  0.0652  0.0450
# 2013-12  0.0303 -0.0041  0.0297  0.0702  0.0775 -0.0195  0.0083  0.0065
# ...

# %%
quiz_part2 = data['2013':'2017']

# %%
l = ['Books', 'Steel', 'Oil', 'Mines']
riskfree_rate = 0.1

er = erk.annualize_rets(quiz_part2[l], 12)
cov = quiz_part2.cov().loc[l,l]

# %%
w_msr = erk.msr(riskfree_rate, er, cov)
w_gmv = erk.gmv(cov)

# %%
w_msr
# Out:
# array([4.63865057e-15, 1.00000000e+00, 1.86482774e-16, 0.00000000e+00])

# %%
w_gmv
# Out:
# array([0.47702486, 0.        , 0.43411204, 0.0888631 ])

# %%
erk.portfolio_vol(w_msr, data['2018'][l].cov())*np.sqrt(12)
# Out:
# 0.21983988181484146

# %%
erk.portfolio_vol(w_gmv, data['2018'][l].cov())*np.sqrt(12)
# Out:
# 0.18973734621505792
